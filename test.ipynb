# %%
import xml.etree.ElementTree as ET

# %%
annotation_path = "VOCdevkit/VOC2007/Annotations/000005.xml"

# %%
tree = ET.parse(annotation_path)

# %%
root = tree.getroot()
tree

# %%
x = root.find('object')

# %%
x
# Out:
# <Element 'object' at 0x1048d92b0>

# %%
print(x)
# Out:
# <Element 'object' at 0x1048d92b0>

# %%
bbox = x.find('bndbox')
xmin = bbox.find('xmin').text
xmin
# Out:
# '263'

# %%
print(type(xmin))
# Out:
# <class 'str'>

# %%
import config
config.img_size
# Out:
# 416
